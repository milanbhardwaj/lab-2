# %%
import nltk

text1 = 'hello he heloo hello hi '
text1 = text1.split(' ')
fdist1 = nltk.FreqDist(text1)
print (fdist1.most_common(50))
# Out:
# [('hello', 2), ('he', 1), ('heloo', 1), ('hi', 1), ('', 1)]

# %%
import os
import nltk.corpus
hemlet=nltk.corpus.gutenberg.words('shakespeare-hamlet.txt')
fdist1 = nltk.FreqDist(hemlet)
print (fdist1.most_common())
# Out:
# [(',', 2892), ('.', 1886), ('the', 860), ("'", 729), ('and', 606), ('of', 576), ('to', 576), (':', 565), ('I', 553), ('you', 479), ('?', 459), ('a', 449), ('my', 435), ('in', 359), ('it', 354), ('Ham', 337), ('is', 304), (';', 298), ('not', 286), ('his', 266), ('And', 257), ('that', 257), ('your', 233), ('this', 232), ('me', 227), ('d', 223), ('with', 212), ('Lord', 211), ('him', 178), ('be', 176), ('King', 172), ('for', 169), ('haue', 161), ('he', 160), ('but', 146), ('so', 145), ('as', 142), ('The', 133), ('will', 131), ('on', 123), ('s', 122), ('That', 120), ('our', 118), ('-', 117), ('what', 116), ('are', 113), ('To', 109), ('shall', 104), ('But', 103), ('Hamlet', 99), ('we', 98), ('Hor', 95), ('What', 95), ('all', 95), ('thou', 93), ('by', 91), ('no', 91), ('her', 90), ('t', 89), ('do', 84), ('more', 83), ('thy', 83), ('Enter', 82), ('from', 80), ('was', 77), ('For', 76), ('good', 76), ('Oh', 76), ('then', 75), ('like', 73), ('or', 73), ('they', 72), ('come', 70), ('know', 70), ('at', 69), ('now', 68), ('them', 67), ('My', 67), ('there', 66), ('selfe', 66), ('most', 65), ('if', 65), ('It', 65), ('vs', 64), ('As', 63), ('A', 62), ('let', 62), ('Qu', 62), ('would', 60), ('well', 60), ('Laer', 60), ('thee', 58), ('Ile', 58), ('may', 56), ('Ophe', 56), ('too', 55), ('How', 55), ('th', 54), ('must', 53), ('should', 52), ('did', 52), ('am', 50), ('If', 49), ('hath', 49), ('out', 49), ('Pol', 49), ('You', 48), ('speake', 48), ('an', 48), ('Why', 47), ('Sir', 47), ('such', 46), ('Father', 46), ('No', 46), ('loue', 46), ('their', 46), ('make', 45), ('(', 45), ('very', 44), ('So', 44), ('This', 44), ('say', 44), ('see', 44), ('doe', 44), (')', 43), ('Rosin', 43), ('He', 42), ('much', 42), ('thinke', 42), ('With', 42), ('some', 42), ('heere', 42), ('Let', 42), ('man', 42), ('In', 41), ('mine', 41), ('Horatio', 40), ('one', 40), ('vpon', 39), ('giue', 39), ('tis', 39), ('which', 39), ('tell', 39), ('Queene', 39), ('had', 38), ('Polon', 38), ('time', 37), ('Mother', 37), ('O', 36), ('Heauen', 36), ('death', 36), ('go', 36), ('Laertes', 35), ('she', 35), ('againe', 34), ('Of', 34), ('vp', 34), ('these', 34), ('Come', 34), ('how', 34), ('can', 33), ('Then', 33), ('thus', 33), ('where', 32), ('Mar', 31), ('owne', 31), ('o', 31), ('Tis', 30), ('heare', 30), ('life', 30), ('Or', 30), ('We', 30), ('night', 29), ('made', 29), ('st', 29), ('Clo', 29), ('downe', 28), ('might', 28), ('Ophelia', 28), ('hast', 27), ('dead', 27), ('when', 27), ('yet', 27), ('God', 26), ('cannot', 26), ('could', 26), ('There', 26), ('Nay', 25), ('&', 25), ('thing', 25), ('matter', 25), ('Play', 25), ('Who', 24), ('heart', 24), ('When', 24), ('Where', 24), ('Is', 24), ('Now', 24), ('leaue', 24), ('were', 24), ('nothing', 23), ('away', 23), ('doth', 23), ('done', 23), ('re', 23), ('Exeunt', 23), ('into', 23), ('l', 23), ('take', 22), ('comes', 22), ('true', 22), ('Good', 22), ('day', 22), ('world', 22), ('head', 22), ('both', 22), ('call', 22), ('two', 21), ('ha', 21), ('hold', 21), ('Ghost', 21), ('Which', 21), ('i', 21), ('put', 21), ('Giue', 20), ('seene', 20), ('Denmarke', 20), ('Do', 20), ('pray', 20), ('Polonius', 20), ('Your', 20), ('Loue', 20), ('set', 20), ('Guild', 20), ('England', 20), ('whose', 19), ('those', 19), ('His', 19), ('shew', 19), ('Fathers', 19), ('faire', 19), ('off', 19), ('sweet', 19), ('great', 19), ('poore', 19), ('himselfe', 19), ('Players', 19), ('who', 18), ('Exit', 18), ('eyes', 18), ('once', 18), ('hand', 18), ('nor', 18), ('looke', 18), ('Nature', 18), ('Sonne', 18), ('indeed', 18), ('play', 18), ('feare', 18), ('Soule', 18), ('meanes', 18), ('Will', 18), ('They', 18), ('Osr', 18), ('Haue', 17), ('against', 17), ('part', 17), ('any', 17), ('deere', 17), ('!', 17), ('eare', 17), ('does', 17), ('words', 17), ('end', 17), ('neuer', 17), ('mad', 17), ('Guildensterne', 17), ('By', 16), ('though', 16), ('about', 16), ('old', 16), ('first', 16), ('Be', 16), ('hee', 16), ('keepe', 16), ('follow', 16), ('liue', 15), ('while', 15), ('sir', 15) ...

# %%
import collections
from nltk.corpus import stopwords

from collections import Counter 


Counter = Counter(hemlet) 
most_occur = Counter.most_common(5) 
  
print(most_occur)
# Out:
# [(',', 2892), ('.', 1886), ('the', 860), ("'", 729), ('and', 606)]

# %%
from nltk.corpus import wordnet
syns = wordnet.synsets("bank")
print("defination:")
print(syns[0].definition())
print("example:")
print(syns[0].examples())
# Out:
# defination:
# sloping land (especially the slope beside a body of water)
# example:
# ['they pulled the canoe up on the bank', 'he sat on the bank of the river and watched the currents']
